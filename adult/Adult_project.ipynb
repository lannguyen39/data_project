# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filepath = r"D:\Docs\TRY HARD TIME\Data_project\adult\adult.csv"

adult = pd.read_csv(filepath)

# %%
adult.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
adult.education.value_counts()
# Out:
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64

# %%
adult.describe
# Out:
# <bound method NDFrame.describe of        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %% [markdown]
# ## Analysis

# %%
#PLot for ages
sns.displot(data= adult.age,kde = True)

# %%
# Create plot for workclass
adult['workclass'].value_counts().plot(kind='bar', xlabel='class', ylabel='Count', rot=90)
plt.figure(figsize=(20, 12))

# %%
#DROP rows where workclass is ? or occupation is ?

i = adult[((adult.workclass == '?') & (adult.occupation == '?'))].index
adult = adult.drop(i)
adult.workclass.value_counts()
# Out:
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64

# %%
#PLot for education

#drop rows that have children under 9th class
j = adult[(adult.education.isin(['9th','7th-8th','5th-6th','1st-4th','Preschool']))].index
adult = adult.drop(j)
adult.education.value_counts()

adult['education'].value_counts().plot(kind='bar', xlabel='class', ylabel='Count', rot= 90)
# Out:
# <Axes: xlabel='class', ylabel='Count'>

# %%
adult['marital-status'].value_counts().plot(kind='bar', xlabel='class', ylabel='Count', rot= 90)
# Out:
# <Axes: xlabel='class', ylabel='Count'>

# %%
adult.occupation.value_counts()
# Out:
# Prof-specialty       6148
# Exec-managerial      6022
# Craft-repair         5691
# Adm-clerical         5554
# Sales                5390
# Other-service        4457
# Machine-op-inspct    2648
# Transport-moving     2155
# Handlers-cleaners    1844
# Tech-support         1436
# Farming-fishing      1238
# Protective-serv       961
# Priv-house-serv       173
# Armed-Forces           15
# ?                       9
# Name: occupation, dtype: int64

# %%
#There's still occupation with ? catagory. So we're going to drop those rows
k = adult[((adult.occupation == '?'))].index
adult = adult.drop(k)
adult.occupation.value_counts()
# Out:
# Prof-specialty       6148
# Exec-managerial      6022
# Craft-repair         5691
# Adm-clerical         5554
# Sales                5390
# Other-service        4457
# Machine-op-inspct    2648
# Transport-moving     2155
# Handlers-cleaners    1844
# Tech-support         1436
# Farming-fishing      1238
# Protective-serv       961
# Priv-house-serv       173
# Armed-Forces           15
# Name: occupation, dtype: int64

# %%
adult['relationship'].value_counts().plot(kind='bar', xlabel='class', ylabel='Count', rot= 90)
# Out:
# <Axes: xlabel='class', ylabel='Count'>

# %%
adult['race'].value_counts().plot(kind='bar', xlabel='class', ylabel='Count', rot= 90)
# Out:
# <Axes: xlabel='class', ylabel='Count'>

# %%
adult['gender'].value_counts().plot(kind='bar', xlabel='class', ylabel='Count', rot= 90)
# Out:
# <Axes: xlabel='class', ylabel='Count'>

# %%
adult['capital-gain'].value_counts().plot(kind='bar', xlabel='class', ylabel='Count', rot= 90)


#this data shows how capital gain is right-skewed
# Out:
# <Axes: xlabel='class', ylabel='Count'>

# %%
adult['capital-loss'].value_counts().plot(kind='bar', xlabel='class', ylabel='Count', rot= 90)

#same with capital loss
# Out:
# <Axes: xlabel='class', ylabel='Count'>

# %%
#distribution plot for hours worked
sns.displot(data= adult['hours-per-week'],kde = True)
plt.figure(figsize=(14, 8))

# %%
adult['native-country'].value_counts()

#There's ? data, so we have to remove them

l = adult[((adult['native-country'] == '?'))].index
adult = adult.drop(l)
adult['native-country'].value_counts()
# Out:
# United-States                 39914
# Mexico                          427
# Philippines                     262
# Germany                         191
# Canada                          154
# India                           145
# Puerto-Rico                     140
# England                         116
# Cuba                            109
# China                           101
# South                           100
# Jamaica                          98
# Japan                            88
# El-Salvador                      80
# Italy                            77
# Vietnam                          75
# Poland                           75
# Columbia                         72
# Dominican-Republic               63
# Iran                             56
# Taiwan                           55
# Haiti                            55
# Guatemala                        48
# Greece                           45
# Peru                             43
# Nicaragua                        41
# ...

# %%
adult['native-country'].value_counts().plot(kind='bar', xlabel='class', ylabel='Count', rot= 90)
plt.figure(figsize=(16, 10))

# %% [markdown]
# ## Impact on target variable (income)

# %%
plt.figure(figsize=(20,5))
sns.catplot(x="age", hue="income", kind="count",col="gender", data=adult)
plt.legend(loc='upper left')
plt.ylabel('Count', fontsize=15, fontweight='bold')
plt.xlabel('Age', fontsize=15, fontweight='bold')
plt.title('Income Distribution With Respect To age', fontsize=15, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Income Distribution With Respect To age')

# %%
plt.figure(figsize=(20,8))
sns.countplot(x=adult['hours-per-week'], hue=adult['occupation'], palette='Set1')
plt.legend(loc='upper left')
plt.ylabel('Count', fontsize=15, fontweight='bold')
plt.xlabel('Hours worked', fontsize=15, fontweight='bold')
plt.title('Occupation Distribution With Respect To Hours worked per week', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.countplot(x=adult['workclass'], hue=adult['income'], palette='Set2')
plt.legend(loc='upper left')
plt.ylabel('Count', fontsize=15, fontweight='bold')
plt.xlabel('Work Class', fontsize=15, fontweight='bold')
plt.title('Income Distribution With Respect To Work Class', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.countplot(x=adult['gender'], hue=adult['income'], palette='Set3')
plt.legend(loc='upper left')
plt.ylabel('Count', fontsize=15, fontweight='bold')
plt.xlabel('Gender', fontsize=15, fontweight='bold')
plt.title('Income Distribution With Respect To Gener', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.countplot(x= adult['education'], hue=adult['occupation'], palette="Set2")
plt.legend(loc='upper left')
plt.ylabel('Occupation Distribution', fontsize=15, fontweight='bold')
plt.xlabel('Education', fontsize=15, fontweight='bold')
plt.title('Occupation Distribution With Respect To Education', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.countplot(x= adult['education'], hue=adult['occupation'], palette="Set2")
plt.legend(loc='upper left')
plt.ylabel('Occupation Distribution', fontsize=15, fontweight='bold')
plt.xlabel('Education', fontsize=15, fontweight='bold')
plt.title('Occupation Distribution With Respect To Education', fontsize=15, fontweight='bold')
plt.show()

# %% [markdown]
# ## Implimentation

# %%
#CLASSIFICATION
X = adult.iloc[1:, 0:14].values
y = adult.iloc[1:, -1].values

from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder() 
X[:, 1] = label.fit_transform(X[:, 1])


X[:, 3] = label.fit_transform(X[:, 3])
X[:, 5] = label.fit_transform(X[:, 5])
X[:, 6] = label.fit_transform(X[:, 6])
X[:, 7] = label.fit_transform(X[:, 7])
X[:, 8] = label.fit_transform(X[:, 8])
X[:, 9] = label.fit_transform(X[:, 9])
X[:, 13] = label.fit_transform(X[:, 13])

# %%
y = label.fit_transform(y)
label.classes_
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
columnTransformer = ColumnTransformer([('Work Class', OneHotEncoder(), [1])], remainder='passthrough')
X=np.array(columnTransformer.fit_transform(X),dtype=np.float64)
columnTransformer = ColumnTransformer([('Education', OneHotEncoder(), [1])], remainder='passthrough')
X=np.array(columnTransformer.fit_transform(X),dtype=np.float64)
columnTransformer = ColumnTransformer([('Marital Status', OneHotEncoder(), [1])], remainder='passthrough')
X=np.array(columnTransformer.fit_transform(X),dtype=np.float64)
columnTransformer = ColumnTransformer([('Occupation', OneHotEncoder(), [1])], remainder='passthrough')
X=np.array(columnTransformer.fit_transform(X),dtype=np.float64)
columnTransformer = ColumnTransformer([('Relationship', OneHotEncoder(), [1])], remainder='passthrough')
X=np.array(columnTransformer.fit_transform(X),dtype=np.float64)
columnTransformer = ColumnTransformer([('Race', OneHotEncoder(), [1])], remainder='passthrough')
X=np.array(columnTransformer.fit_transform(X),dtype=np.float64)
columnTransformer = ColumnTransformer([('Gender', OneHotEncoder(), [1])], remainder='passthrough')
X=np.array(columnTransformer.fit_transform(X),dtype=np.float64)
columnTransformer = ColumnTransformer([('Native Country', OneHotEncoder(), [1])], remainder='passthrough')
X=np.array(columnTransformer.fit_transform(X),dtype=np.float64)

# %%
X.shape
# Out:
# (42979, 43)

# %%
K = [] 
training = [] 
test = [] 
scores = {} 

#SPLIT
X_train, X_test, y_train, y_test = train_test_split(X ,y)
 
#K_NN
for k in range(2, 21): 
    clf = KNeighborsClassifier(n_neighbors = k) 
    clf.fit(X_train, y_train) 
  
    training_score = clf.score(X_train, y_train) 
    test_score = clf.score(X_test, y_test) 
    K.append(k) 
  
    training.append(training_score) 
    test.append(test_score) 
    scores[k] = [training_score, test_score]

# %%
for keys, values in scores.items(): 
    print(keys, ':', values)
# Out:
# 2 : [0.8641806787863746, 0.7703117729176361]
# 3 : [0.8598374387292921, 0.7420195439739413]
# 4 : [0.8290004343240057, 0.772080037226617]
# 5 : [0.8250604951293665, 0.7565379246161005]
# 6 : [0.8121238443879134, 0.7769194974406701]
# 7 : [0.8114723583793509, 0.7686365751512332]
# 8 : [0.8047093131476081, 0.780269892973476]
# 9 : [0.8042749891418999, 0.7727315030246626]
# 10 : [0.7986598002109574, 0.7842717543043276]
# 11 : [0.799497425079109, 0.7808282922289437]
# 12 : [0.7968604579015945, 0.7823173569101908]
# 13 : [0.7972947819073029, 0.7812936249418334]
# 14 : [0.7953403238816157, 0.7825034899953467]
# 15 : [0.795526462741205, 0.7816658911121452]
# 16 : [0.7943165601538748, 0.7829688227082364]
# 17 : [0.7946578147297885, 0.7822242903676129]
# 18 : [0.7924241484147174, 0.7828757561656584]
# 19 : [0.79301358813675, 0.7838064215914379]
# 20 : [0.7917106161196252, 0.7844578873894835]

# %%
plt.scatter(K, training, color ='Blue') 
plt.scatter(K, test, color ='Red') 
plt.show()

#From the plot and the score report, k=3 is the best predictor.
